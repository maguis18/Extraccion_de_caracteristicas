# %%
# %pip install funpymodeling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.3/325.3 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 35.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 33.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 11.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f26f28b2-3ed5-4741-afb7-41d301a1fedf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f26f28b2-3ed5-4741-afb7-41d301a1fedf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Bozeman=pd.read_csv('Datos_limpios_Bozeman.csv')

# %%
Bozeman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 49 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0       last_scraped                567 non-null    object
#  1   source                          567 non-null    object
#  2   name                            567 non-null    object
#  3   description                     567 non-null    object
#  4   host_name                       567 non-null    object
#  5   host_since                      567 non-null    object
#  6   host_location                   567 non-null    object
#  7   host_about                      567 non-null    object
#  8   host_response_time              567 non-null    object
#  9   host_response_rate              567 non-null    object
#  10  host_acceptance_rate            567 non-null    object
#  11  host_is_superhost               567 non-null    object
# ...

# %%
Bozeman.head()
# Out:
#    Unnamed: 0     last_scraped       source  \
# 0           0       09/11/2024  city scrape
# 1           1       09/11/2024  city scrape
# 2           2       09/11/2024  city scrape
# 3           3       09/11/2024  city scrape
# 4           4       09/11/2024  city scrape
#
#                                  name  \
# 0         Unique neighborhood cottage
# 1    Downtown Bozeman Vacation Rental
# 2                  Northside Hideaway
# 3                     2 Blocks 2 Main
# 4  Modern Home Near Campus & Downtown
#
#                                          description      host_name  \
# 0  Not for everyone, but loved by many'<br />' Th...         Stacie
# 1  Just four easy blocks from historic downtown B...          Brian
# 2  Free, fast Wi-Fi for remote learning/working n...           Paul
# 3  This space is designed for 1-2 people that wan...          Irene
# 4  Great house on the south side of town, near ca...  Kris And Alex
#
#    host_since   host_location  \
# ...

# %%
Bozeman=Bozeman.drop(columns='Unnamed: 0')
Bozeman
# Out:
#         last_scraped       source  \
# 0         09/11/2024  city scrape
# 1         09/11/2024  city scrape
# 2         09/11/2024  city scrape
# 3         09/11/2024  city scrape
# 4         09/11/2024  city scrape
# ..               ...          ...
# 562       09/11/2024  city scrape
# 563       09/11/2024  city scrape
# 564       09/11/2024  city scrape
# 565       09/11/2024  city scrape
# 566       09/11/2024  city scrape
#
#                                                   name  \
# 0                          Unique neighborhood cottage
# 1                     Downtown Bozeman Vacation Rental
# 2                                   Northside Hideaway
# 3                                      2 Blocks 2 Main
# 4                   Modern Home Near Campus & Downtown
# ..                                                 ...
# 562                         Lofted live/work apartment
# 563  Experience the Romance of The Historic Rouse H...
# ...

# %%
freq_tbl(Bozeman)

# %% [markdown]
# # 1.Host Response Time

# %%
table1=freq_tbl(Bozeman['host_response_time'])
table1
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour        472    0.832451         0.832451
# 1        within a day         61    0.107584         0.940035
# 2  within a few hours         30    0.052910         0.992945
# 3  a few days or more          4    0.007055         1.000000

# %%
table2=table1.drop(['percentage','cumulative_perc'],axis=1)
table2
# Out:
#    host_response_time  frequency
# 0      within an hour        472
# 1        within a day         61
# 2  within a few hours         30
# 3  a few days or more          4

# %%
filtro_index=table2.set_index('host_response_time')
filtro_index
# Out:
#                     frequency
# host_response_time
# within an hour            472
# within a day               61
# within a few hours         30
# a few days or more          4

# %%
filtro_index.plot(kind='line', marker='o', figsize=(10, 4), color="blue")

plt.title('Tiempo de respuesta del host')
plt.xlabel('Categorías')
plt.ylabel('Frecuencia')
plt.grid(True)  # Agrega una rejilla para mejor visualización
plt.show()

# %% [markdown]
# # 2. Source

# %%
table_source=freq_tbl(Bozeman['source'])
table_source

# %%
table_source2=table_source.drop(['percentage','cumulative_perc'],axis=1)
table_source2

# %%
filtro_source=table_source2.set_index('source')
filtro_source

# %%
filtro_source.plot(kind='bar',width=0.8, figsize=(10,4),color="blue")
plt.title('Fuente')
plt.xlabel('categorias')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# # 3.Host name

# %%
table_name=freq_tbl(Bozeman['host_name'])
table_name

# %%
table_name2=table_name.drop(['percentage','cumulative_perc'],axis=1)
table_name2

# %%
filtro_name=table_name2[table_name2['frequency']>10]
filtro_name

# %%
filtro_name2=filtro_name.set_index('host_name')
filtro_name2

# %%
filtro_name2.plot(kind='line', marker='o', figsize=(10, 4), color="blue")

plt.title('Nombre del host')
plt.xlabel('Categorías')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# # 4.host_since

# %%
table_since=freq_tbl(Bozeman['host_since'])
table_since

# %%
table_since2=table_since.drop(['percentage','cumulative_perc'],axis=1)
table_since2

# %%
filtro_since=table_since2[table_since2['frequency']>10]
filtro_since

# %%
filtro_since2=filtro_since.set_index('host_since')
filtro_since2

# %%
filtro_since2.plot(kind='area', alpha=0.6, figsize=(10, 4), color="blue")

plt.title('Fecha de inicio del host')
plt.xlabel('Categorías')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# # 5.Host location

# %%
table_location=freq_tbl(Bozeman['host_location'])
table_location

# %%
table_location2=table_location.drop(['percentage','cumulative_perc'],axis=1)
table_location2

# %%
filtro_location=table_location2[table_location2['frequency']>2]
filtro_location

# %%
filtro_location2=filtro_location.set_index('host_location')
filtro_location2

# %%
filtro_location2.plot(kind='line', marker='o', figsize=(10, 4), color="blue")

plt.title('Nombre de la locacion')
plt.xlabel('Categorías')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# # 6.host_about

# %%
table_about=freq_tbl(Bozeman['host_about'])
table_about

# %%
table_about2=table_about.drop(['percentage','cumulative_perc'],axis=1)
table_about2

# %%
filtro_about=table_about2[table_about2['frequency']>10]
filtro_about

# %%
filtro_about2=filtro_about.set_index('host_about')
filtro_about2

# %%
import seaborn as sns

# %%
filtro_about2["frequency"].plot(kind='pie',figsize=(10,5),shadow=True,autopct='%1.1f%%')
# Out:
# <Axes: ylabel='frequency'>
# ) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 7.host_response_rate

# %%
table_response_rate=freq_tbl(Bozeman['host_response_rate'])
table_response_rate
# Out:
#   host_response_rate  frequency  percentage  cumulative_perc
# 0               100%        415    0.731922         0.731922
# 1                98%         47    0.082892         0.814815
# 2                97%         41    0.072310         0.887125
# 3                90%         26    0.045855         0.932981
# 4                99%         23    0.040564         0.973545
# 5                67%          5    0.008818         0.982363
# 6                 0%          4    0.007055         0.989418
# 7                83%          3    0.005291         0.994709
# 8                50%          2    0.003527         0.998236
# 9                88%          1    0.001764         1.000000

# %%
table_response_rate2=table_response_rate.drop(['percentage','cumulative_perc'],axis=1)
table_response_rate2
# Out:
#   host_response_rate  frequency
# 0               100%        415
# 1                98%         47
# 2                97%         41
# 3                90%         26
# 4                99%         23
# 5                67%          5
# 6                 0%          4
# 7                83%          3
# 8                50%          2
# 9                88%          1

# %%
filtro_response_rate=table_response_rate2[table_response_rate2['frequency']>=5]
filtro_response_rate
# Out:
#   host_response_rate  frequency
# 0               100%        415
# 1                98%         47
# 2                97%         41
# 3                90%         26
# 4                99%         23
# 5                67%          5

# %%
filtro_response_rate2=filtro_response_rate.set_index('host_response_rate')
filtro_response_rate2
# Out:
#                     frequency
# host_response_rate
# 100%                      415
# 98%                        47
# 97%                        41
# 90%                        26
# 99%                        23
# 67%                         5

# %%
filtro_response_rate2.plot(kind='line', marker='o', figsize=(10, 4), color="blue")

plt.title('Rate del respose del host')
plt.xlabel('Categorías')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# # 8.host_acceptance_rate

# %%
table_acceptance_rate=freq_tbl(Bozeman['host_acceptance_rate'])
table_acceptance_rate
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%        277    0.488536         0.488536
# 1                   99%        127    0.223986         0.712522
# 2                   95%         41    0.072310         0.784832
# 3                   98%         27    0.047619         0.832451
# 4                   97%         11    0.019400         0.851852
# 5                   93%          8    0.014109         0.865961
# 6                    0%          7    0.012346         0.878307
# 7                   96%          7    0.012346         0.890653
# 8                   92%          7    0.012346         0.902998
# 9                   50%          6    0.010582         0.913580
# 10                  80%          4    0.007055         0.920635
# 11                  94%          4    0.007055         0.927690
# 12                  91%          3    0.005291         0.932981
# 13                  75%          3    0.005291         0.938272
# ...

# %%
table_acceptance_rate2=table_acceptance_rate.drop(['percentage','cumulative_perc'],axis=1)
table_acceptance_rate2
# Out:
#    host_acceptance_rate  frequency
# 0                  100%        277
# 1                   99%        127
# 2                   95%         41
# 3                   98%         27
# 4                   97%         11
# 5                   93%          8
# 6                    0%          7
# 7                   96%          7
# 8                   92%          7
# 9                   50%          6
# 10                  80%          4
# 11                  94%          4
# 12                  91%          3
# 13                  75%          3
# 14                  83%          3
# 15                  24%          3
# 16                  65%          2
# 17                  77%          2
# 18                  33%          2
# 19                  79%          2
# 20                  89%          2
# 21                  17%          2
# 22                  86%          2
# 23                  84%          1
# 24                  67%          1
# 25                  38%          1
# ...

# %%
filtro_accepteance_rate=table_acceptance_rate2[table_acceptance_rate2['frequency']>10]
filtro_accepteance_rate
# Out:
#   host_acceptance_rate  frequency
# 0                 100%        277
# 1                  99%        127
# 2                  95%         41
# 3                  98%         27
# 4                  97%         11

# %%
filtro_accepteance_rate2=filtro_accepteance_rate.set_index('host_acceptance_rate')
filtro_accepteance_rate2
# Out:
#                       frequency
# host_acceptance_rate
# 100%                        277
# 99%                         127
# 95%                          41
# 98%                          27
# 97%                          11

# %%
filtro_accepteance_rate2.plot(kind='area', alpha=0.6, figsize=(10, 4), color="blue")

plt.title('Tasa de aceptacion del host')
plt.xlabel('Categorías')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# # 9.host_is_superhost

# %%
table_superhost=freq_tbl(Bozeman['host_is_superhost'])
table_superhost
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 t        374    0.659612         0.659612
# 1                 f        193    0.340388         1.000000

# %%
table_superhost2=table_superhost.drop(['percentage','cumulative_perc'],axis=1)
table_superhost2
# Out:
#   host_is_superhost  frequency
# 0                 t        374
# 1                 f        193

# %%
filtro_superhost=table_superhost2.set_index('host_is_superhost')
filtro_superhost
# Out:
#                    frequency
# host_is_superhost
# t                        374
# f                        193

# %%
filtro_superhost.plot(kind='bar',width=0.8, figsize=(10,4),color="blue")
plt.title('Superhost')
plt.xlabel('categorias')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# # 10.host_verifications

# %%
table_verifications=freq_tbl(Bozeman['host_verifications'])
table_verifications
# Out:
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']        445    0.784832         0.784832
# 1  ['email', 'phone', 'work_email']         95    0.167549         0.952381
# 2                         ['phone']         25    0.044092         0.996473
# 3                         ['email']          2    0.003527         1.000000

# %%
table_verifications2=table_verifications.drop(['percentage','cumulative_perc'],axis=1)
table_verifications2
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']        445
# 1  ['email', 'phone', 'work_email']         95
# 2                         ['phone']         25
# 3                         ['email']          2

# %%
filtro_verifications=table_verifications2.set_index('host_verifications')
filtro_verifications
# Out:
#                                   frequency
# host_verifications
# ['email', 'phone']                      445
# ['email', 'phone', 'work_email']         95
# ['phone']                                25
# ['email']                                 2

# %%
filtro_verifications.plot(kind='line', marker='o', figsize=(10, 4), color="blue")

plt.title('Verificaciones del host')
plt.xlabel('Categorías')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# # 11.host_has_profile_pic

# %%
table_profile_pic=freq_tbl(Bozeman['host_has_profile_pic'])
table_profile_pic
# Out:
#   host_has_profile_pic  frequency  percentage  cumulative_perc
# 0                    t        557    0.982363         0.982363
# 1                    f         10    0.017637         1.000000

# %%
table_profile_pic2=table_profile_pic.drop(['percentage','cumulative_perc'],axis=1)
table_profile_pic2
# Out:
#   host_has_profile_pic  frequency
# 0                    t        557
# 1                    f         10

# %%
filtro_profile_pic=table_profile_pic2.set_index('host_has_profile_pic')
filtro_profile_pic
# Out:
#                       frequency
# host_has_profile_pic
# t                           557
# f                            10

# %%
filtro_profile_pic.plot(kind='bar',width=0.8, figsize=(10,4),color="blue")
plt.title('Perfil de host')
plt.xlabel('categorias')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# # 12.host_identity_verified

# %%
table_indetity=freq_tbl(Bozeman['host_identity_verified'])
table_indetity
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t        489    0.862434         0.862434
# 1                      f         78    0.137566         1.000000

# %%
table_indetity2=table_indetity.drop(['percentage','cumulative_perc'],axis=1)
table_indetity2
# Out:
#   host_identity_verified  frequency
# 0                      t        489
# 1                      f         78

# %%
filtro_identity=table_indetity2.set_index('host_identity_verified')
filtro_identity
# Out:
#                         frequency
# host_identity_verified
# t                             489
# f                              78

# %%
filtro_identity["frequency"].plot(kind='pie',figsize=(10,5),shadow=True,autopct='%1.1f%%')
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# # 13.property_type

# %%
table_property=freq_tbl(Bozeman['property_type'])
table_property
# Out:
#                  property_type  frequency  percentage  cumulative_perc
# 0                  Entire home        189    0.333333         0.333333
# 1                 Entire condo        104    0.183422         0.516755
# 2           Entire rental unit        100    0.176367         0.693122
# 3             Entire townhouse         57    0.100529         0.793651
# 4            Entire guesthouse         37    0.065256         0.858907
# 5         Private room in home         23    0.040564         0.899471
# 6           Entire guest suite         20    0.035273         0.934744
# 7       Room in boutique hotel          5    0.008818         0.943563
# 8               Entire cottage          5    0.008818         0.952381
# 9               Room in hostel          4    0.007055         0.959436
# 10   Private room in townhouse          4    0.007055         0.966490
# 11             Entire bungalow          3    0.005291         0.971781
# ...

# %%
table_property2=table_property.drop(['percentage','cumulative_perc'],axis=1)
table_property2
# Out:
#                  property_type  frequency
# 0                  Entire home        189
# 1                 Entire condo        104
# 2           Entire rental unit        100
# 3             Entire townhouse         57
# 4            Entire guesthouse         37
# 5         Private room in home         23
# 6           Entire guest suite         20
# 7       Room in boutique hotel          5
# 8               Entire cottage          5
# 9               Room in hostel          4
# 10   Private room in townhouse          4
# 11             Entire bungalow          3
# 12  Private room in guesthouse          3
# 13                 Entire loft          3
# 14       Private room in condo          2
# 15               Entire chalet          1
# 16                Entire cabin          1
# 17       Shared room in hostel          1
# 18                   Camper/RV          1
# 19        Entire vacation home          1
# 20                Entire villa          1
# ...

# %%
filtro_property=table_property2[table_property2['frequency']>10]
filtro_property
# Out:
#           property_type  frequency
# 0           Entire home        189
# 1          Entire condo        104
# 2    Entire rental unit        100
# 3      Entire townhouse         57
# 4     Entire guesthouse         37
# 5  Private room in home         23
# 6    Entire guest suite         20

# %%
filtro_property2=filtro_property.set_index('property_type')
filtro_property2
# Out:
#                       frequency
# property_type
# Entire home                 189
# Entire condo                104
# Entire rental unit          100
# Entire townhouse             57
# Entire guesthouse            37
# Private room in home         23
# Entire guest suite           20

# %%
filtro_property2.plot(kind='bar',width=0.8, figsize=(10,4),color="blue")
plt.title('Tipo de propiedad')
plt.xlabel('categorias')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# # 14.room_type

# %%
table_room=freq_tbl(Bozeman['room_type'])
table_room
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt        525    0.925926         0.925926
# 1     Private room         37    0.065256         0.991182
# 2       Hotel room          4    0.007055         0.998236
# 3      Shared room          1    0.001764         1.000000

# %%
table_room2=table_room.drop(['percentage','cumulative_perc'],axis=1)
table_room2
# Out:
#          room_type  frequency
# 0  Entire home/apt        525
# 1     Private room         37
# 2       Hotel room          4
# 3      Shared room          1

# %%
filtro_room=table_room2.set_index('room_type')
filtro_room
# Out:
#                  frequency
# room_type
# Entire home/apt        525
# Private room            37
# Hotel room               4
# Shared room              1

# %%
filtro_room.plot(kind='bar',width=0.8, figsize=(10,4),color="pink")
plt.title('Tipo de habitación')
plt.xlabel('categorias')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# # 15.amenities

# %%
tabla_amenities=freq_tbl(Bozeman['amenities'])
tabla_amenities
# Out:
#                                              amenities  frequency  percentage  \
# 0    ["Refrigerator", "Private entrance", "Hangers"...          6    0.010582
# 1    ["Refrigerator", "Luggage dropoff allowed", "B...          3    0.005291
# 2    ["Exterior security cameras on property", "Wif...          2    0.003527
# 3    ["Refrigerator", "Luggage dropoff allowed", "P...          2    0.003527
# 4    ["Refrigerator", "Patio or balcony", "Carbon m...          2    0.003527
# ..                                                 ...        ...         ...
# 549  ["Refrigerator", "Private entrance", "Hangers"...          1    0.001764
# 550  ["Refrigerator", "Private entrance", "Portable...          1    0.001764
# 551  ["Children\u2019s dinnerware", "Refrigerator",...          1    0.001764
# 552  ["Children\u2019s dinnerware", "Free residenti...          1    0.001764
# 553  ["Refrigerator", "Heating - split type ductles...          1    0.001764
#
#      cumulative_perc
# ...

# %%
tabla_amenities2=tabla_amenities.drop(['percentage','cumulative_perc'],axis=1)
tabla_amenities2
# Out:
#                                              amenities  frequency
# 0    ["Refrigerator", "Private entrance", "Hangers"...          6
# 1    ["Refrigerator", "Luggage dropoff allowed", "B...          3
# 2    ["Exterior security cameras on property", "Wif...          2
# 3    ["Refrigerator", "Luggage dropoff allowed", "P...          2
# 4    ["Refrigerator", "Patio or balcony", "Carbon m...          2
# ..                                                 ...        ...
# 549  ["Refrigerator", "Private entrance", "Hangers"...          1
# 550  ["Refrigerator", "Private entrance", "Portable...          1
# 551  ["Children\u2019s dinnerware", "Refrigerator",...          1
# 552  ["Children\u2019s dinnerware", "Free residenti...          1
# 553  ["Refrigerator", "Heating - split type ductles...          1
#
# [554 rows x 2 columns]

# %%
filtro_amenities=tabla_amenities2[tabla_amenities2['frequency']>1]
filtro_amenities
# Out:
#                                            amenities  frequency
# 0  ["Refrigerator", "Private entrance", "Hangers"...          6
# 1  ["Refrigerator", "Luggage dropoff allowed", "B...          3
# 2  ["Exterior security cameras on property", "Wif...          2
# 3  ["Refrigerator", "Luggage dropoff allowed", "P...          2
# 4  ["Refrigerator", "Patio or balcony", "Carbon m...          2
# 5  ["Refrigerator", "Luggage dropoff allowed", "B...          2
# 6  ["Hangers", "Patio or balcony", "Carbon monoxi...          2
# 7  ["Refrigerator", "Private entrance", "Patio or...          2

# %%
filtro_amenities2=filtro_amenities.set_index('amenities')
filtro_amenities2
# Out:
#                                                     frequency
# amenities
# ["Refrigerator", "Private entrance", "Hangers",...          6
# ["Refrigerator", "Luggage dropoff allowed", "Bu...          3
# ["Exterior security cameras on property", "Wifi...          2
# ["Refrigerator", "Luggage dropoff allowed", "Pr...          2
# ["Refrigerator", "Patio or balcony", "Carbon mo...          2
# ["Refrigerator", "Luggage dropoff allowed", "Bu...          2
# ["Hangers", "Patio or balcony", "Carbon monoxid...          2
# ["Refrigerator", "Private entrance", "Patio or ...          2

# %%
filtro_amenities2["frequency"].plot(kind='pie',figsize=(10,5),shadow=True,autopct='%1.1f%%')
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# # 16.price

# %%
table_price=freq_tbl(Bozeman['price'])
table_price
# Out:
#      price  frequency  percentage  cumulative_perc
# 0     198%         34    0.059965         0.059965
# 1     150%         15    0.026455         0.086420
# 2     175%         10    0.017637         0.104056
# 3     120%         10    0.017637         0.121693
# 4     165%         10    0.017637         0.139330
# ..     ...        ...         ...              ...
# 224    38%          1    0.001764         0.992945
# 225   172%          1    0.001764         0.994709
# 226   202%          1    0.001764         0.996473
# 227    40%          1    0.001764         0.998236
# 228  1092%          1    0.001764         1.000000
#
# [229 rows x 4 columns]

# %%
table_price2=table_price.drop(['percentage','cumulative_perc'],axis=1)
table_price2
# Out:
#      price  frequency
# 0     198%         34
# 1     150%         15
# 2     175%         10
# 3     120%         10
# 4     165%         10
# ..     ...        ...
# 224    38%          1
# 225   172%          1
# 226   202%          1
# 227    40%          1
# 228  1092%          1
#
# [229 rows x 2 columns]

# %%
filtro_price=table_price2[table_price2['frequency']>=10]
filtro_price
# Out:
#   price  frequency
# 0  198%         34
# 1  150%         15
# 2  175%         10
# 3  120%         10
# 4  165%         10

# %%
filtro_price2=filtro_price.set_index('price')
filtro_price2
# Out:
#        frequency
# price
# 198%          34
# 150%          15
# 175%          10
# 120%          10
# 165%          10

# %%
filtro_price2["frequency"].plot(kind='pie',figsize=(10,5),shadow=True,autopct='%1.1f%%')
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# # 17.has_availability

# %%
table_availability=freq_tbl(Bozeman['has_availability'])
table_availability
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t        559    0.985891         0.985891
# 1                f          8    0.014109         1.000000

# %%
table_availability2=table_availability.drop(['percentage','cumulative_perc'],axis=1)
table_availability2
# Out:
#   has_availability  frequency
# 0                t        559
# 1                f          8

# %%
filtro_availability=table_availability2.set_index('has_availability')
filtro_availability
# Out:
#                   frequency
# has_availability
# t                       559
# f                         8

# %%
filtro_availability.plot(kind='bar',width=0.8, figsize=(10,4),color="blue")
plt.title('Disponibilidad')
plt.xlabel('categorias')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# # 18.first_review

# %%
table_firts_review=freq_tbl(Bozeman['first_review'])
table_firts_review
# Out:
#     first_review  frequency  percentage  cumulative_perc
# 0     2018-01-01         74    0.130511         0.130511
# 1     31/05/2024          3    0.005291         0.135802
# 2     13/05/2024          3    0.005291         0.141093
# 3     04/10/2021          3    0.005291         0.146384
# 4     20/11/2022          3    0.005291         0.151675
# ..           ...        ...         ...              ...
# 428   29/11/2020          1    0.001764         0.992945
# 429   19/06/2020          1    0.001764         0.994709
# 430   22/06/2021          1    0.001764         0.996473
# 431   20/06/2020          1    0.001764         0.998236
# 432   04/10/2024          1    0.001764         1.000000
#
# [433 rows x 4 columns]

# %%
table_firts_review2=table_firts_review.drop(['percentage','cumulative_perc'],axis=1)
table_firts_review2
# Out:
#     first_review  frequency
# 0     2018-01-01         74
# 1     31/05/2024          3
# 2     13/05/2024          3
# 3     04/10/2021          3
# 4     20/11/2022          3
# ..           ...        ...
# 428   29/11/2020          1
# 429   19/06/2020          1
# 430   22/06/2021          1
# 431   20/06/2020          1
# 432   04/10/2024          1
#
# [433 rows x 2 columns]

# %%
filtro_first_review=table_firts_review2[table_firts_review2['frequency']>2]
filtro_first_review
# Out:
#    first_review  frequency
# 0    2018-01-01         74
# 1    31/05/2024          3
# 2    13/05/2024          3
# 3    04/10/2021          3
# 4    20/11/2022          3
# 5    17/10/2021          3
# 6    13/02/2022          3
# 7    02/10/2022          3
# 8    30/06/2022          3
# 9    11/07/2022          3
# 10   26/03/2022          3
# 11   07/11/2021          3

# %%
filtro_first_review2=filtro_first_review.set_index('first_review')
filtro_first_review2
# Out:
#               frequency
# first_review
# 2018-01-01           74
# 31/05/2024            3
# 13/05/2024            3
# 04/10/2021            3
# 20/11/2022            3
# 17/10/2021            3
# 13/02/2022            3
# 02/10/2022            3
# 30/06/2022            3
# 11/07/2022            3
# 26/03/2022            3
# 07/11/2021            3

# %%
filtro_first_review2["frequency"].plot(kind='pie',figsize=(10,5),shadow=True,autopct='%1.1f%%')
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# # 19.last_review

# %%
table_last_review=freq_tbl(Bozeman['last_review'])
table_last_review
# Out:
#     last_review  frequency  percentage  cumulative_perc
# 0    2024-10-01         74    0.130511         0.130511
# 1    13/10/2024         35    0.061728         0.192240
# 2    20/10/2024         21    0.037037         0.229277
# 3    14/10/2024         21    0.037037         0.266314
# 4    21/10/2024         21    0.037037         0.303351
# ..          ...        ...         ...              ...
# 144  01/06/2024          1    0.001764         0.992945
# 145  18/07/2023          1    0.001764         0.994709
# 146  02/10/2024          1    0.001764         0.996473
# 147  10/05/2024          1    0.001764         0.998236
# 148  09/10/2024          1    0.001764         1.000000
#
# [149 rows x 4 columns]

# %%
table_last_review2=table_last_review.drop(['percentage','cumulative_perc'],axis=1)
table_last_review2
# Out:
#     last_review  frequency
# 0    2024-10-01         74
# 1    13/10/2024         35
# 2    20/10/2024         21
# 3    14/10/2024         21
# 4    21/10/2024         21
# ..          ...        ...
# 144  01/06/2024          1
# 145  18/07/2023          1
# 146  02/10/2024          1
# 147  10/05/2024          1
# 148  09/10/2024          1
#
# [149 rows x 2 columns]

# %%
filtro_last_review=table_last_review2[table_last_review2['frequency']>12]
filtro_last_review
# Out:
#   last_review  frequency
# 0  2024-10-01         74
# 1  13/10/2024         35
# 2  20/10/2024         21
# 3  14/10/2024         21
# 4  21/10/2024         21
# 5  25/10/2024         17
# 6  03/11/2024         13
# 7  29/10/2024         13

# %%
filtro_last_review2=filtro_last_review.set_index('last_review')
filtro_last_review2
# Out:
#              frequency
# last_review
# 2024-10-01          74
# 13/10/2024          35
# 20/10/2024          21
# 14/10/2024          21
# 21/10/2024          21
# 25/10/2024          17
# 03/11/2024          13
# 29/10/2024          13

# %%
filtro_last_review2.plot(kind='bar',width=0.8, figsize=(10,4),color="red")
plt.title('Última reseña')
plt.xlabel('categorias')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# # 20.instant_bookable

# %%
table_instant_bookable=freq_tbl(Bozeman['instant_bookable'])
table_instant_bookable
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f        323    0.569665         0.569665
# 1                t        244    0.430335         1.000000

# %%
table_instant_bookable2=table_instant_bookable.drop(['percentage','cumulative_perc'],axis=1)
table_instant_bookable2
# Out:
#   instant_bookable  frequency
# 0                f        323
# 1                t        244

# %%
filtro_instant_bookable=table_instant_bookable2.set_index('instant_bookable')
filtro_instant_bookable
# Out:
#                   frequency
# instant_bookable
# f                       323
# t                       244

# %%
filtro_instant_bookable.plot(kind='bar',width=0.8, figsize=(10,4),color="blue")
plt.title('instant_bookable')
plt.xlabel('categorias')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# # **PARTE 2**

# %% [markdown]
# # 1.host_total_listings_count

# %%
Bozeman['host_total_listings_count'].info()
n=567

# %%
max_listings_count=Bozeman['host_total_listings_count'].max()
min_listings_count=Bozeman['host_total_listings_count'].min()
limites_listings_count=[min_listings_count,max_listings_count]
limites_listings_count
# Out:
# [1.0, 46.0]

# %%
r_listings_counut=max_listings_count-min_listings_count
r_listings_counut
# Out:
# 45.0

# %%
ni=1+3.32*np.log10(n)
ni
# Out:
# 10.141895755524448

# %%
i=r_listings_counut/ni
i
# Out:
# 4.437040281693666

# %%
intervalos_listings_count=np.linspace(min_listings_count,max_listings_count,11)
intervalos_listings_count
# Out:
# array([ 1. ,  5.5, 10. , 14.5, 19. , 23.5, 28. , 32.5, 37. , 41.5, 46. ])

# %%
categorias_listings_count=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
Bozeman['host_total_listings_count']=pd.cut(x=Bozeman['host_total_listings_count'],bins=intervalos_listings_count, labels=categorias_listings_count)
Bozeman['host_total_listings_count']
# Out:
# 0             NaN
# 1      categoria1
# 2      categoria9
# 3      categoria1
# 4      categoria1
#           ...
# 562           NaN
# 563    categoria2
# 564    categoria4
# 565    categoria2
# 566           NaN
# Name: host_total_listings_count, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # 2.accommodates

# %%
Bozeman['accommodates'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
max_accommodates=Bozeman['accommodates'].max()
min_accommodates=Bozeman['accommodates'].min()
limites_accommodates=[min_accommodates,max_accommodates]
limites_accommodates
# Out:
# [1.0, 10.0]

# %%
r_accommodates=max_accommodates-min_accommodates
r_accommodates
# Out:
# 9.0

# %%
ni_accommodates=1+3.32*np.log10(n)
ni_accommodates
# Out:
# 10.141895755524448

# %%
i_accommodates=r_accommodates/ni
i_accommodates
# Out:
# 0.8874080563387333

# %%
intervalos_accommodates=np.linspace(min_accommodates,max_accommodates,11)
intervalos_accommodates
# Out:
# array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ])

# %%
categorias_accommodates=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
Bozeman['accommodates']=pd.cut(x=Bozeman['accommodates'],bins=intervalos_accommodates, labels=categorias_accommodates)
Bozeman['accommodates']
# Out:
# 0      categoria2
# 1      categoria2
# 2      categoria4
# 3      categoria2
# 4      categoria6
#           ...
# 562    categoria4
# 563    categoria2
# 564    categoria2
# 565    categoria8
# 566    categoria4
# Name: accommodates, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %%
import seaborn as sns
frecuencia_accommodates = Bozeman['accommodates'].value_counts().sort_index()

# Crear el gráfico de barras
plt.figure(figsize=(10, 5))
sns.barplot(x=frecuencia_accommodates.index, y=frecuencia_accommodates.values, palette="viridis")

# Etiquetas y título
plt.xlabel("Categorías de accommodates")
plt.ylabel("Frecuencia")
plt.title("Distribución de accommodates en Bozeman")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # 4.beds

# %%
Bozeman['beds'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
max_beds=Bozeman['beds'].max()
min_beds=Bozeman['beds'].min()
limites_beds=[min_beds,max_beds]
limites_beds
# Out:
# [1.0, 4.0]

# %%
r_beds=max_beds-min_beds
r_beds
# Out:
# 3.0

# %%
ni_beds=1+3.32*np.log10(n)
ni_beds
# Out:
# 10.141895755524448

# %%
intervalo_beds=r_beds/ni
intervalo_beds
# Out:
# 0.29580268544624444

# %%
intervalos_beds=np.linspace(min_beds,max_beds,11)
intervalos_beds
# Out:
# array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ])

# %%
categorias_beds=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
Bozeman['beds']=pd.cut(x=Bozeman['beds'],bins=intervalos_beds, labels=categorias_beds)
Bozeman['beds']
# Out:
# 0       categoria4
# 1              NaN
# 2       categoria4
# 3              NaN
# 4       categoria7
#           ...
# 562     categoria4
# 563            NaN
# 564            NaN
# 565    categoria10
# 566            NaN
# Name: beds, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # 5.price

# %%
Bozeman['price'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    object
# dtypes: object(1)
# memory usage: 4.6+ KB

# %%
max_price=Bozeman['price'].max()
min_price=Bozeman['price'].min()
limites_price=[min_price,max_price]
limites_price
# Out:
# nan

# %%
r_price=max_price-min_price
r_price
# Out:
# nan

# %%
ni=1+3.32*np.log10(n)
ni
# Out:
# 10.141895755524448

# %%
i_price=r_price/ni
i_price
# Out:
# nan

# %%
intervalos_price=np.linspace(min_price,max_price,11)
intervalos_price
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
categorias_price=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
Bozeman['price']=pd.cut(x=Bozeman['price'],bins=intervalos_price, labels=categorias_price)
Bozeman['price']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-b88493727d54> in <cell line: 0>()
# ----> 1 Bozeman['price']=pd.cut(x=Bozeman['price'],bins=intervalos_price, labels=categorias_price)
#       2 Bozeman['price']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     253         bins = Index(bins)
#     254         if not bins.is_monotonic_increasing:
# --> 255             raise ValueError("bins must increase monotonically.")
#     256
#     257     fac, bins = _bins_to_cuts(
#
# ValueError: bins must increase monotonically.

# %% [markdown]
# # 6.maximum_nights_avg_ntm

# %%
Bozeman['maximum_nights_avg_ntm'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: maximum_nights_avg_ntm
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      category
# dtypes: category(1)
# memory usage: 1.1 KB

# %%
max_maximum_nights_avg_ntm=Bozeman['maximum_nights_avg_ntm'].max()
min_maximum_nights_avg_ntm=Bozeman['maximum_nights_avg_ntm'].min()
limites_maximum_nights_avg_ntm=[min_maximum_nights_avg_ntm,max_maximum_nights_avg_ntm]
limites_maximum_nights_avg_ntm
# Out:
# [nan, nan]

# %%
r_maximum_nights_avg_ntm=max_maximum_nights_avg_ntm-min_maximum_nights_avg_ntm
r_maximum_nights_avg_ntm
# Out:
# nan

# %%
ni_maximum_nights_avg_ntm=1+3.32*np.log10(n)
ni_maximum_nights_avg_ntm
# Out:
# 10.141895755524448

# %%
i_maximum_nights_avg_ntm=r_maximum_nights_avg_ntm/ni_maximum_nights_avg_ntm
i_maximum_nights_avg_ntm
# Out:
# 110.63020435689542

# %%
intervalos_maximum_nights_avg_ntm=np.linspace(min_maximum_nights_avg_ntm,max_maximum_nights_avg_ntm,11)
intervalos_maximum_nights_avg_ntm
# Out:
# array([   3. ,  115.2,  227.4,  339.6,  451.8,  564. ,  676.2,  788.4,
#         900.6, 1012.8, 1125. ])

# %%
categorias_maximum_nights_avg_ntm=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
Bozeman['maximum_nights_avg_ntm']=pd.cut(x=Bozeman['maximum_nights_avg_ntm'],bins=intervalos_maximum_nights_avg_ntm, labels=categorias_maximum_nights_avg_ntm)
Bozeman['maximum_nights_avg_ntm']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 562    NaN
# 563    NaN
# 564    NaN
# 565    NaN
# 566    NaN
# Name: maximum_nights_avg_ntm, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # 7.availability_365

# %%
Bozeman['availability_365'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    int64
# dtypes: int64(1)
# memory usage: 4.6 KB

# %%
max_availability_365=Bozeman['availability_365'].max()
min_availability_365=Bozeman['availability_365'].min()
limites_availability_365=[min_availability_365,max_availability_365]
limites_availability_365
# Out:
# [0, 365]

# %%
r_availability_365=max_availability_365-min_availability_365
r_availability_365
# Out:
# 365

# %%
ni=1+3.32*np.log10(n)
ni
# Out:
# 10.141895755524448

# %%
i_availability_365=r_availability_365/ni
i_availability_365
# Out:
# 35.989326729293076

# %%
intervalos_availability_365=np.linspace(min_availability_365,max_availability_365,11)
intervalos_availability_365
# Out:
# array([  0. ,  36.5,  73. , 109.5, 146. , 182.5, 219. , 255.5, 292. ,
#        328.5, 365. ])

# %%
categorias_availability_365=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
Bozeman['availability_365']=pd.cut(x=Bozeman['availability_365'],bins=intervalos_availability_365, labels=categorias_availability_365)
Bozeman['availability_365']
# Out:
# 0       categoria3
# 1       categoria8
# 2      categoria10
# 3       categoria7
# 4      categoria10
#           ...
# 562     categoria5
# 563    categoria10
# 564    categoria10
# 565     categoria9
# 566    categoria10
# Name: availability_365, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # 8.number_of_reviews

# %%
Bozeman['number_of_reviews_ltm'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: number_of_reviews_ltm
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
max_number_of_reviews_ltm=Bozeman['number_of_reviews_ltm'].max()
min_number_of_reviews_ltm=Bozeman['number_of_reviews_ltm'].min()
limites_number_of_reviews_ltm=[min_number_of_reviews_ltm,max_number_of_reviews_ltm]
limites_number_of_reviews_ltm
# Out:
# [0.0, 67.0]

# %%
r_number_of_reviews_ltm=max_number_of_reviews_ltm-min_number_of_reviews_ltm
r_number_of_reviews_ltm
# Out:
# 67.0

# %%
ni_number_of_reviews_ltm=1+3.32*np.log10(n)
ni_number_of_reviews_ltm
# Out:
# 10.141895755524448

# %%
i_number_of_reviews_ltm=r_number_of_reviews_ltm/ni_number_of_reviews_ltm
i_number_of_reviews_ltm
# Out:
# 6.606259974966126

# %%
intervalos_number_of_reviews_ltm=np.linspace(min_number_of_reviews_ltm,max_number_of_reviews_ltm,11)
intervalos_number_of_reviews_ltm
# Out:
# array([ 0. ,  6.7, 13.4, 20.1, 26.8, 33.5, 40.2, 46.9, 53.6, 60.3, 67. ])

# %%
categorias_number_of_reviews_ltm=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
Bozeman['number_of_reviews_ltm']=pd.cut(x=Bozeman['number_of_reviews_ltm'],bins=intervalos_number_of_reviews_ltm, labels=categorias_number_of_reviews_ltm)
Bozeman['number_of_reviews_ltm']
# Out:
# 0      categoria4
# 1      categoria3
# 2      categoria1
# 3      categoria1
# 4      categoria7
#           ...
# 562           NaN
# 563           NaN
# 564           NaN
# 565           NaN
# 566           NaN
# Name: number_of_reviews_ltm, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # 9.review_scores_location

# %%
Bozeman['review_scores_location'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
max_review_scores_location=Bozeman['review_scores_location'].max()
min_review_scores_location=Bozeman['review_scores_location'].min()
limites_review_scores_location=[min_review_scores_location,max_review_scores_location]
limites_review_scores_location
# Out:
# [4.77, 5.0]

# %%
r_review_scores_location=max_review_scores_location-min_review_scores_location
r_review_scores_location
# Out:
# 0.23000000000000043

# %%
ni_review_scores_location=1+3.32*np.log10(n)
ni_review_scores_location
# Out:
# 10.141895755524448

# %%
i_review_scores_location=r_review_scores_location/ni_review_scores_location
i_review_scores_location
# Out:
# 0.022678205884212117

# %%
intervalos_review_scores_location=np.linspace(min_review_scores_location,max_review_scores_location,11)
intervalos_review_scores_location
# Out:
# array([4.77 , 4.793, 4.816, 4.839, 4.862, 4.885, 4.908, 4.931, 4.954,
#        4.977, 5.   ])

# %%
categorias_review_scores_location=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
Bozeman['review_scores_location']=pd.cut(x=Bozeman['review_scores_location'],bins=intervalos_review_scores_location, labels=categorias_review_scores_location)
Bozeman['review_scores_location']
# Out:
# 0      categoria10
# 1       categoria7
# 2       categoria9
# 3      categoria10
# 4       categoria6
#           ...
# 562     categoria6
# 563     categoria6
# 564     categoria6
# 565     categoria6
# 566     categoria6
# Name: review_scores_location, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # 10.review_scores_value

# %%
Bozeman['review_scores_value'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
max_review_scores_value=Bozeman['review_scores_value'].max()
min_review_scores_value=Bozeman['review_scores_value'].min()
limites_review_scores_value=[min_review_scores_value,max_review_scores_value]
limites_review_scores_value
# Out:
# [4.62, 5.0]

# %%
  r_review_scores_value=max_review_scores_value-min_review_scores_value
r_review_scores_value
# Out:
# 0.3799999999999999

# %%
  ni_review_scores_value=1+3.32*np.log10(n)
ni_review_scores_value
# Out:
# 10.141895755524448

# %%
  i_review_scores_value=r_review_scores_value/ni_review_scores_value
i_review_scores_value
# Out:
# 0.03746834015652428

# %%
  intervalos_review_scores_value=np.linspace(min_review_scores_value,max_review_scores_value,11)
intervalos_review_scores_value
# Out:
# array([4.62 , 4.658, 4.696, 4.734, 4.772, 4.81 , 4.848, 4.886, 4.924,
#        4.962, 5.   ])

# %%
  categorias_review_scores_value=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
  Bozeman['review_scores_value']=pd.cut(x=Bozeman['review_scores_value'],bins=intervalos_review_scores_value, labels=categorias_review_scores_value)
Bozeman['review_scores_value']
# Out:
# 0      categoria8
# 1      categoria9
# 2      categoria3
# 3      categoria3
# 4      categoria3
#           ...
# 562    categoria5
# 563    categoria5
# 564    categoria5
# 565    categoria5
# 566    categoria5
# Name: review_scores_value, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # 11.reviews_per_month

# %%
Bozeman['reviews_per_month'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
  max_reviews_per_month=Bozeman['reviews_per_month'].max()
min_reviews_per_month=Bozeman['reviews_per_month'].min()
limites_reviews_per_month=[min_reviews_per_month,max_reviews_per_month]
limites_reviews_per_month
# Out:
# [0.01, 5.35]

# %%
  r_reviews_per_month=max_reviews_per_month-min_reviews_per_month
r_reviews_per_month
# Out:
# 5.34

# %%
  ni_reviews_per_month=1+3.32*np.log10(n)
ni_reviews_per_month
# Out:
# 10.141895755524448

# %%
  i_reviews_per_month=r_reviews_per_month/ni_reviews_per_month
i_reviews_per_month
# Out:
# 0.5265287800943151

# %%
  intervalos_reviews_per_month=np.linspace(min_reviews_per_month,max_reviews_per_month,11)
intervalos_reviews_per_month
# Out:
# array([0.01 , 0.544, 1.078, 1.612, 2.146, 2.68 , 3.214, 3.748, 4.282,
#        4.816, 5.35 ])

# %%
  categorias_reviews_per_month=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
    Bozeman['reviews_per_month']=pd.cut(x=Bozeman['reviews_per_month'],bins=intervalos_reviews_per_month, labels=categorias_reviews_per_month)
Bozeman['reviews_per_month']
# Out:
# 0      categoria4
# 1      categoria8
# 2      categoria1
# 3      categoria1
# 4      categoria5
#           ...
# 562    categoria4
# 563    categoria4
# 564    categoria4
# 565    categoria4
# 566    categoria4
# Name: reviews_per_month, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # **12.review_scores_communication**

# %%
  Bozeman['review_scores_communication'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
  max_review_scores_communication=Bozeman['review_scores_communication'].max()
min_review_scores_communication=Bozeman['review_scores_communication'].min()
limites_review_scores_communication=[min_review_scores_communication,max_review_scores_communication]
limites_review_scores_communication
# Out:
# [4.76, 5.0]

# %%
  r_review_scores_communication=max_review_scores_communication-min_review_scores_communication
r_review_scores_communication
# Out:
# 0.2400000000000002

# %%
  ni_review_scores_communication=1+3.32*np.log10(n)
ni_review_scores_communication
# Out:
# 10.141895755524448

# %%
    i_review_scores_communication=r_review_scores_communication/ni_review_scores_communication
i_review_scores_communication
# Out:
# 0.023664214835699575

# %%
  intervalos_review_scores_communication=np.linspace(min_review_scores_communication,max_review_scores_communication,11)
intervalos_review_scores_communication
# Out:
# array([4.76 , 4.784, 4.808, 4.832, 4.856, 4.88 , 4.904, 4.928, 4.952,
#        4.976, 5.   ])

# %%
  categorias_review_scores_communication=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
  Bozeman['review_scores_communication']=pd.cut(x=Bozeman['review_scores_communication'],bins=intervalos_review_scores_communication, labels=categorias_review_scores_communication)
Bozeman['review_scores_communication']
# Out:
# 0      categoria10
# 1      categoria10
# 2       categoria9
# 3      categoria10
# 4       categoria3
#           ...
# 562     categoria6
# 563     categoria6
# 564     categoria6
# 565     categoria6
# 566     categoria6
# Name: review_scores_communication, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # 13.review_scores_checkin

# %%
  Bozeman['review_scores_checkin'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
  max_review_scores_checkin=Bozeman['review_scores_checkin'].max()
min_review_scores_checkin=Bozeman['review_scores_checkin'].min()
limites_review_scores_checkin=[min_review_scores_checkin,max_review_scores_checkin]
limites_review_scores_checkin
# Out:
# [4.77, 5.0]

# %%
  r_review_scores_checkin=max_review_scores_checkin-min_review_scores_checkin
r_review_scores_checkin
# Out:
# 0.23000000000000043

# %%
  ni_review_scores_checkin=1+3.32*np.log10(n)
ni_review_scores_checkin
# Out:
# 10.141895755524448

# %%
  i_review_scores_checkin=r_review_scores_checkin/ni_review_scores_checkin
i_review_scores_checkin
# Out:
# 0.022678205884212117

# %%
  intervalos_review_scores_checkin=np.linspace(min_review_scores_checkin,max_review_scores_checkin,11)
intervalos_review_scores_checkin
# Out:
# array([4.77 , 4.793, 4.816, 4.839, 4.862, 4.885, 4.908, 4.931, 4.954,
#        4.977, 5.   ])

# %%
  categorias_review_scores_checkin=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
  Bozeman['review_scores_checkin']=pd.cut(x=Bozeman['review_scores_checkin'],bins=intervalos_review_scores_checkin, labels=categorias_review_scores_checkin)
Bozeman['review_scores_checkin']
# Out:
# 0      categoria10
# 1       categoria9
# 2       categoria8
# 3      categoria10
# 4       categoria7
#           ...
# 562     categoria6
# 563     categoria6
# 564     categoria6
# 565     categoria6
# 566     categoria6
# Name: review_scores_checkin, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # 14.review_scores_cleanliness

# %%
  Bozeman['review_scores_cleanliness'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
  max_review_scores_cleanliness=Bozeman['review_scores_cleanliness'].max()
min_review_scores_cleanliness=Bozeman['review_scores_cleanliness'].min()
limites_review_scores_cleanliness=[min_review_scores_cleanliness,max_review_scores_cleanliness]
limites_review_scores_cleanliness
# Out:
# [4.76, 5.0]

# %%
  r_review_scores_cleanliness=max_review_scores_cleanliness-min_review_scores_cleanliness
r_review_scores_cleanliness
# Out:
# 0.2400000000000002

# %%
  ni_review_scores_cleanliness=1+3.32*np.log10(n)
ni_review_scores_cleanliness
# Out:
# 10.141895755524448

# %%
  i_review_scores_cleanliness=r_review_scores_cleanliness/ni_review_scores_cleanliness
i_review_scores_cleanliness
# Out:
# 0.023664214835699575

# %%
  intervalos_review_scores_cleanliness=np.linspace(min_review_scores_cleanliness,max_review_scores_cleanliness,11)
intervalos_review_scores_cleanliness
# Out:
# array([4.76 , 4.784, 4.808, 4.832, 4.856, 4.88 , 4.904, 4.928, 4.952,
#        4.976, 5.   ])

# %%
    categorias_review_scores_cleanliness=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
  Bozeman['review_scores_cleanliness']=pd.cut(x=Bozeman['review_scores_cleanliness'],bins=intervalos_review_scores_cleanliness, labels=categorias_review_scores_cleanliness)
Bozeman['review_scores_cleanliness']
# Out:
# 0       categoria9
# 1       categoria8
# 2       categoria3
# 3      categoria10
# 4       categoria6
#           ...
# 562     categoria6
# 563     categoria6
# 564     categoria6
# 565     categoria6
# 566     categoria6
# Name: review_scores_cleanliness, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']

# %% [markdown]
# # 15.review_scores_accuracy

# %%
  Bozeman['review_scores_accuracy'].info()
n=567
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 567 entries, 0 to 566
# Series name: review_scores_accuracy
# Non-Null Count  Dtype
# --------------  -----
# 567 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
  max_review_scores_accuracy=Bozeman['review_scores_accuracy'].max()
min_review_scores_accuracy=Bozeman['review_scores_accuracy'].min()
limites_review_scores_accuracy  =[min_review_scores_accuracy,max_review_scores_accuracy]
limites_review_scores_accuracy
# Out:
# [4.76, 5.0]

# %%
  r_review_scores_accuracy=max_review_scores_accuracy-min_review_scores_accuracy
r_review_scores_accuracy
# Out:
# 0.2400000000000002

# %%
  ni_review_scores_accuracy=1+3.32*np.log10(n)
ni_review_scores_accuracy
# Out:
# 10.141895755524448

# %%
  i_review_scores_accuracy=r_review_scores_accuracy/ni_review_scores_accuracy
i_review_scores_accuracy
# Out:
# 0.023664214835699575

# %%
  intervalos_review_scores_accuracy=np.linspace(min_review_scores_accuracy,max_review_scores_accuracy,11)
intervalos_review_scores_accuracy
# Out:
# array([4.76 , 4.784, 4.808, 4.832, 4.856, 4.88 , 4.904, 4.928, 4.952,
#        4.976, 5.   ])

# %%
  categorias_review_scores_accuracy=["categoria1","categoria2", "categoria3", "categoria4", "categoria5",
            "categoria6", "categoria7", "categoria8", "categoria9", "categoria10"]

# %%
  Bozeman['review_scores_accuracy']=pd.cut(x=Bozeman['review_scores_accuracy'],bins=intervalos_review_scores_accuracy, labels=categorias_review_scores_accuracy)
Bozeman['review_scores_accuracy']
# Out:
# 0       categoria8
# 1      categoria10
# 2       categoria6
# 3      categoria10
# 4       categoria5
#           ...
# 562     categoria6
# 563     categoria6
# 564     categoria6
# 565     categoria6
# 566     categoria6
# Name: review_scores_accuracy, Length: 567, dtype: category
# Categories (10, object): ['categoria1' < 'categoria2' < 'categoria3' < 'categoria4' ... 'categoria7' <
#                           'categoria8' < 'categoria9' < 'categoria10']
